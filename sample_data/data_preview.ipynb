# %%
import pandas as pd

# %%
airbnb_500 = pd.read_csv('airbnb_listing_500.csv')
airbnb_500.head()
# Out:
#                     id                                       listing_url  \
# 0  1142371205159311574  https://www.airbnb.com/rooms/1142371205159311574
# 1             53622717             https://www.airbnb.com/rooms/53622717
# 2   810975480795788954   https://www.airbnb.com/rooms/810975480795788954
# 3  1111648956960973361  https://www.airbnb.com/rooms/1111648956960973361
# 4  1274185726978391147  https://www.airbnb.com/rooms/1274185726978391147
#
#         scrape_id last_scraped       source  \
# 0  20241206031821   2024-12-06  city scrape
# 1  20241206031821   2024-12-06  city scrape
# 2  20241206031821   2024-12-07  city scrape
# 3  20241206031821   2024-12-06  city scrape
# 4  20241206031821   2024-12-06  city scrape
#
#                                                 name  \
# 0  King Bed & Private Bath in Mid-City LA / Korea...
# 1      Beautiful 4 bdrm w/ parking close to LAX/SoFi
# 2                                  Ocean Dreams Flat
# ...

# %%
airbnb_500.shape
# Out:
# (500, 75)
